# %%
import json
import pandas as pd

# %%
cities = json.load(open("city_list.json", "r"))

# %%
# check that reading worked
print(cities[1:10])
# Out:
# [{'id': 2960, 'name': '‘Ayn Ḩalāqīm', 'state': '', 'country': 'SY', 'coord': {'lon': 36.321911, 'lat': 34.940079}}, {'id': 3245, 'name': 'Taglag', 'state': '', 'country': 'IR', 'coord': {'lon': 44.98333, 'lat': 38.450001}}, {'id': 3530, 'name': 'Qabāghlū', 'state': '', 'country': 'IR', 'coord': {'lon': 46.168499, 'lat': 36.173302}}, {'id': 5174, 'name': '‘Arīqah', 'state': '', 'country': 'SY', 'coord': {'lon': 36.48336, 'lat': 32.889809}}, {'id': 7264, 'name': 'Kalāteh-ye Dowlat', 'state': '', 'country': 'IR', 'coord': {'lon': 57.616982, 'lat': 36.163841}}, {'id': 8084, 'name': 'Behjatābād', 'state': '', 'country': 'IR', 'coord': {'lon': 51.461639, 'lat': 36.667431}}, {'id': 9874, 'name': 'Ţālesh Maḩalleh', 'state': '', 'country': 'IR', 'coord': {'lon': 50.679192, 'lat': 36.894329}}, {'id': 11263, 'name': 'Shahrīār Kandeh', 'state': '', 'country': 'IR', 'coord': {'lon': 53.19902, 'lat': 36.631939}}, {'id': 11754, 'name': 'Bālā Aḩmad Kolā', 'state': '', 'country': 'IR', 'coord': {'lon': 52.667271, 'lat': 36.649059}}]

# %%
# filter list to Canadian entries
city_listing = list(filter(lambda entry: entry['name'] == 'Montréal' and entry['country'] == 'CA', cities))[0]

# %%
city_listing['id']
# Out:
# 6077243

# %%
pip install country_converter --upgrade
# Out:
# Collecting country_converter
#   Downloading country_converter-0.7.1.tar.gz (47 kB)
#      |████████████████████████████████| 47 kB 5.9 MB/s  eta 0:00:01
# Requirement already satisfied, skipping upgrade: pandas>=0.17.0 in /home/mkshaw/miniconda3/lib/python3.8/site-packages (from country_converter) (1.1.1)
# Requirement already satisfied, skipping upgrade: python-dateutil>=2.7.3 in /home/mkshaw/miniconda3/lib/python3.8/site-packages (from pandas>=0.17.0->country_converter) (2.8.1)
# Requirement already satisfied, skipping upgrade: numpy>=1.15.4 in /home/mkshaw/miniconda3/lib/python3.8/site-packages (from pandas>=0.17.0->country_converter) (1.19.1)
# Requirement already satisfied, skipping upgrade: pytz>=2017.2 in /home/mkshaw/miniconda3/lib/python3.8/site-packages (from pandas>=0.17.0->country_converter) (2020.1)
# Requirement already satisfied, skipping upgrade: six>=1.5 in /home/mkshaw/miniconda3/lib/python3.8/site-packages (from python-dateutil>=2.7.3->pandas>=0.17.0->country_converter) (1.14.0)
# Building wheels for collected packages: country-converter
#   Building wheel for country-converter (setup.py) ... done
#   Created wheel for country-converter: filename=country_converter-0.7.1-py3-none-any.whl size=50806 sha256=ac8d8a6c6745924bb0e01af63aa7ffb9bb05aa8ec0b2c30f32aa5ba88bb1dc65
#   Stored in directory: /home/mkshaw/.cache/pip/wheels/93/a4/a5/f78c6e79b2b2eb70a1546406ca03339771795190e8b5470474
# Successfully built country-converter
# Installing collected packages: country-converter
# Successfully installed country-converter-0.7.1
# Note: you may need to restart the kernel to use updated packages.

# %%
import country_converter as coco

# %%
country = "Canada"
country_ISO = coco.convert(country, to='ISO2')
print(country)
print(country_ISO)
# Out:
# Canada
# CA

# %%
# import unidecode
import unidecode

# %%
# test unidecode
cities
# Out:
# [{'id': 833,
#   'name': 'Ḩeşār-e Sefīd',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 47.159401, 'lat': 34.330502}},
#  {'id': 2960,
#   'name': '‘Ayn Ḩalāqīm',
#   'state': '',
#   'country': 'SY',
#   'coord': {'lon': 36.321911, 'lat': 34.940079}},
#  {'id': 3245,
#   'name': 'Taglag',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 44.98333, 'lat': 38.450001}},
#  {'id': 3530,
#   'name': 'Qabāghlū',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 46.168499, 'lat': 36.173302}},
#  {'id': 5174,
#   'name': '‘Arīqah',
#   'state': '',
#   'country': 'SY',
#   'coord': {'lon': 36.48336, 'lat': 32.889809}},
#  {'id': 7264,
#   'name': 'Kalāteh-ye Dowlat',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 57.616982, 'lat': 36.163841}},
#  {'id': 8084,
#   'name': 'Behjatābād',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 51.461639, 'lat': 36.667431}},
#  {'id': 9874,
#   'name': 'Ţālesh Maḩalleh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 50.679192, 'lat': 36.894329}},
#  {'id': 11263,
#   'name': 'Shahrīār Kandeh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 53.19902, 'lat': 36.631939}},
#  {'id': 11754,
#   'name': 'Bālā Aḩmad Kolā',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 52.667271, 'lat': 36.649059}},
#  {'id': 12795,
#   'name': 'Aş Şūrah aş Şaghīrah',
#   'state': '',
#   'country': 'SY',
#   'coord': {'lon': 36.573872, 'lat': 33.032669}},
#  {'id': 14177,
#   'name': 'Āqdūz',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 44.26556, 'lat': 39.197498}},
#  {'id': 14256,
#   'name': 'Āzādshahr',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 48.570728, 'lat': 34.790878}},
#  {'id': 18007,
#   'name': 'Gollar',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 46.25, 'lat': 37.383331}},
#  {'id': 18093,
#   'name': 'Dīgāleh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 45.106998, 'lat': 37.552502}},
#  {'id': 18557,
#   'name': 'Qarālar-e Mīrzā Ḩoseynqolī',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 45.067501, 'lat': 37.674702}},
#  {'id': 18918,
#   'name': 'Protaras',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 34.058331, 'lat': 35.012501}},
#  {'id': 23814,
#   'name': 'Kahrīz',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 47.055302, 'lat': 34.383801}},
#  {'id': 24851,
#   'name': 'Nūrābād',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 47.9725, 'lat': 34.073399}},
#  {'id': 29033,
#   'name': 'Rokan Sarā',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 49.608101, 'lat': 37.32085}},
#  {'id': 30321,
#   'name': 'Zīrjān',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 58.43586, 'lat': 34.214401}},
#  {'id': 30485,
#   'name': 'Dahasuways',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 50.729439, 'lat': 15.72389}},
#  {'id': 30490,
#   'name': 'Ash Shihr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.606392, 'lat': 14.75863}},
#  {'id': 30543,
#   'name': 'Al Ghaylah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.583328, 'lat': 14.59583}},
#  {'id': 30616,
#   'name': 'Judaydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.299622, 'lat': 15.07512}},
#  {'id': 30689,
#   'name': 'Dawran',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.441959, 'lat': 13.77436}},
#  {'id': 30696,
#   'name': 'Najd al Jumai',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.324139, 'lat': 13.91581}},
#  {'id': 30714,
#   'name': 'Zalmat al Alya',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.09404, 'lat': 14.1023}},
#  {'id': 30729,
#   'name': 'Suq ar Rabu',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.01511, 'lat': 14.51155}},
#  {'id': 30735,
#   'name': 'Ash Shuqayrah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.786362, 'lat': 13.13452}},
#  {'id': 30740,
#   'name': 'Mashraah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.99588, 'lat': 13.53235}},
#  {'id': 30748,
#   'name': 'Ar Rawnah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.80286, 'lat': 13.75638}},
#  {'id': 30762,
#   'name': 'Ar Ramadi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.784569, 'lat': 13.95641}},
#  {'id': 30777,
#   'name': 'Al Ahad',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.64167, 'lat': 14.25833}},
#  {'id': 30788,
#   'name': 'Ad Dil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.818279, 'lat': 14.67199}},
#  {'id': 30789,
#   'name': 'Al Jabin',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.599041, 'lat': 14.70401}},
#  {'id': 32516,
#   'name': 'Badrābād-e `Olyā',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 48.279442, 'lat': 33.42944}},
#  {'id': 32723,
#   'name': 'Īstgāh-e Rāh Āhan-e Garmsār',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 52.309422, 'lat': 35.23455}},
#  {'id': 32767,
#   'name': 'Qarchak',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 51.56889, 'lat': 35.439442}},
#  {'id': 34703,
#   'name': 'Suq Sirwah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.01667, 'lat': 15.45417}},
#  {'id': 34717,
#   'name': 'Majzar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.775002, 'lat': 15.85}},
#  {'id': 34724,
#   'name': 'Bidbadah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.700001, 'lat': 15.425}},
#  {'id': 34821,
#   'name': 'Matwah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.642132, 'lat': 15.0676}},
#  {'id': 34827,
#   'name': 'Suwayr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.609859, 'lat': 16.181801}},
#  {'id': 34846,
#   'name': 'Wadarah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.483212, 'lat': 15.71073}},
#  {'id': 34862,
#   'name': 'Suq Shamar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.368061, 'lat': 15.885}},
#  {'id': 34886,
#   'name': 'Mustaba',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.248951, 'lat': 16.228161}},
#  {'id': 34888,
#   'name': 'An Nazir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.26226, 'lat': 16.909161}},
#  {'id': 34915,
#   'name': 'Dayr al Ḩisī',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.099998, 'lat': 16.049999}},
#  {'id': 35056,
#   'name': 'Tabrīz Jānī',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 46.23333, 'lat': 38.133331}},
#  {'id': 36741,
#   'name': 'Andīmeshk',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 48.383331, 'lat': 32.533329}},
#  {'id': 37755,
#   'name': 'Ravīndūzaq',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 48.080002, 'lat': 38.4398}},
#  {'id': 39161,
#   'name': 'Māmā’ī',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 54.397739, 'lat': 36.892578}},
#  {'id': 40847,
#   'name': 'Reẕāābād',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 57.31778, 'lat': 37.499722}},
#  {'id': 41210,
#   'name': 'Khorramdarreh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 49.195999, 'lat': 36.213001}},
#  {'id': 41964,
#   'name': 'Kūchaklī',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 50.533329, 'lat': 35.466671}},
#  {'id': 44992,
#   'name': 'Koshtārgāh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 49.166672, 'lat': 30.549999}},
#  {'id': 45013,
#   'name': 'Jozf-e Soflá',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 48.224098, 'lat': 30.365499}},
#  {'id': 49518,
#   'name': 'Republic of Rwanda',
#   'state': '',
#   'country': 'RW',
#   'coord': {'lon': 30.0, 'lat': -2.0}},
#  {'id': 49593,
#   'name': 'Yeed',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.033329, 'lat': 4.55}},
#  {'id': 49747,
#   'name': 'Xuddur',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.88945, 'lat': 4.12129}},
#  {'id': 50064,
#   'name': 'Xarardheere',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 47.857498, 'lat': 4.6544}},
#  {'id': 50360,
#   'name': 'Gobolka Woqooyi Galbeed',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.5, 'lat': 10.0}},
#  {'id': 50672,
#   'name': 'Wanlaweyn',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.893799, 'lat': 2.6185}},
#  {'id': 50814,
#   'name': 'Waajid',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.246281, 'lat': 3.80958}},
#  {'id': 51230,
#   'name': 'Gobolka Togdheer',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.416672, 'lat': 9.33333}},
#  {'id': 51299,
#   'name': 'Tayeeglow',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.51112, 'lat': 4.01897}},
#  {'id': 51537,
#   'name': 'Somalia',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.0, 'lat': 6.0}},
#  {'id': 51966,
#   'name': 'Gobolka Shabeellaha Hoose',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.416672, 'lat': 1.83333}},
#  {'id': 51967,
#   'name': 'Gobolka Shabeellaha Dhexe',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 46.0, 'lat': 3.0}},
#  {'id': 52187,
#   'name': 'Gobolka Sanaag',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.0, 'lat': 10.5}},
#  {'id': 52381,
#   'name': 'Saacow',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.440659, 'lat': 1.62794}},
#  {'id': 52867,
#   'name': 'Qoryooley',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.529991, 'lat': 1.78784}},
#  {'id': 53157,
#   'name': 'Qandala',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.872822, 'lat': 11.47197}},
#  {'id': 53172,
#   'name': 'Qaloocan',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.04784, 'lat': 9.52943}},
#  {'id': 53372,
#   'name': 'Oodweyne',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.063969, 'lat': 9.4092}},
#  {'id': 53477,
#   'name': 'Gobolka Nugaal',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.0, 'lat': 8.16667}},
#  {'id': 53654,
#   'name': 'Mogadishu',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.34375, 'lat': 2.03711}},
#  {'id': 53707,
#   'name': 'Gobolka Mudug',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.0, 'lat': 7.0}},
#  {'id': 54225,
#   'name': 'Marka',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.77166, 'lat': 1.71594}},
#  {'id': 54460,
#   'name': 'Mahaddayweyne',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.534698, 'lat': 2.9726}},
#  {'id': 54715,
#   'name': 'Luuq',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.544498, 'lat': 3.79376}},
#  {'id': 54746,
#   'name': 'Lughaye',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.94397, 'lat': 10.68573}},
#  {'id': 55223,
#   'name': 'Las Khorey',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.196701, 'lat': 11.1595}},
#  {'id': 55671,
#   'name': 'Kismayo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.545361, 'lat': -0.35817}},
#  {'id': 56083,
#   'name': 'Gobolka Jubbada Hoose',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.0, 'lat': 0.0}},
#  {'id': 56084,
#   'name': 'Gobolka Jubbada Dhexe',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.666672, 'lat': 1.33333}},
#  {'id': 56166,
#   'name': 'Jilib',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.785351, 'lat': 0.48829}},
#  {'id': 56335,
#   'name': 'Jawhar',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.500481, 'lat': 2.78087}},
#  {'id': 56399,
#   'name': 'Jamaame',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.744968, 'lat': 0.06968}},
#  {'id': 56414,
#   'name': 'Jalalaqsi',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.599602, 'lat': 3.3766}},
#  {'id': 56505,
#   'name': 'Iskushuban',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 50.23, 'lat': 10.2837}},
#  {'id': 57000,
#   'name': 'Hobyo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.526798, 'lat': 5.3505}},
#  {'id': 57060,
#   'name': 'Gobolka Hiiraan',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.5, 'lat': 4.0}},
#  {'id': 57289,
#   'name': 'Hargeysa',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.064999, 'lat': 9.56}},
#  {'id': 58802,
#   'name': 'Gobolka Gedo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.0, 'lat': 3.0}},
#  {'id': 58933,
#   'name': 'Garoowe',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 48.484459, 'lat': 8.40536}},
#  {'id': 58994,
#   'name': 'Garbahaarrey',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.220909, 'lat': 3.32892}},
#  {'id': 59362,
#   'name': 'Gobolka Galguduud',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 47.0, 'lat': 5.0}},
#  {'id': 59611,
#   'name': 'Gaalkacyo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 47.430828, 'lat': 6.76972}},
#  {'id': 60019,
#   'name': 'Eyl',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.816399, 'lat': 7.9803}},
#  {'id': 60147,
#   'name': 'El Dubat',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.083328, 'lat': 9.51667}},
#  {'id': 60207,
#   'name': 'El Ad',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.150002, 'lat': 11.28333}},
#  {'id': 60457,
#   'name': 'Dujuuma',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.573769, 'lat': 1.25311}},
#  {'id': 60628,
#   'name': 'Doon',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.123329, 'lat': 11.23861}},
#  {'id': 60928,
#   'name': 'Dhuusamarreeb',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 46.386108, 'lat': 5.535}},
#  {'id': 61993,
#   'name': 'Dalooldho',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.06229, 'lat': 9.59271}},
#  {'id': 62660,
#   'name': 'Cheli Gu',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.083328, 'lat': 4.43333}},
#  {'id': 62691,
#   'name': 'Ceerigaabo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 47.36795, 'lat': 10.61616}},
#  {'id': 62788,
#   'name': 'Ceeldheer',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 47.180641, 'lat': 3.84878}},
#  {'id': 62821,
#   'name': 'Ceelbuur',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 46.617599, 'lat': 4.68501}},
#  {'id': 62854,
#   'name': 'Ceek',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.358238, 'lat': 8.99907}},
#  {'id': 63081,
#   'name': 'Caluula',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 50.756939, 'lat': 11.96611}},
#  {'id': 63344,
#   'name': 'Cadale',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 46.322201, 'lat': 2.7603}},
#  {'id': 63571,
#   'name': 'Buurhakaba',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 44.07806, 'lat': 2.80257}},
#  {'id': 63580,
#   'name': 'Buur Gaabo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 41.83736, 'lat': -1.21933}},
#  {'id': 63689,
#   'name': 'Buulobarde',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.56744, 'lat': 3.85375}},
#  {'id': 63795,
#   'name': 'Burao',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.53363, 'lat': 9.52212}},
#  {'id': 63949,
#   'name': 'Bu’aale',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.583328, 'lat': 1.08333}},
#  {'id': 64013,
#   'name': 'Bosaso',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 49.18158, 'lat': 11.28421}},
#  {'id': 64412,
#   'name': 'Bereeda',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 51.057949, 'lat': 11.87037}},
#  {'id': 64435,
#   'name': 'Berbera',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.01432, 'lat': 10.43959}},
#  {'id': 64460,
#   'name': 'Beledweyne',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.203609, 'lat': 4.73583}},
#  {'id': 64480,
#   'name': 'Behelidle',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.316669, 'lat': 2.31667}},
#  {'id': 64536,
#   'name': 'Baidoa',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.649799, 'lat': 3.11383}},
#  {'id': 64538,
#   'name': 'Gobolka Bay',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 43.5, 'lat': 3.0}},
#  {'id': 64661,
#   'name': 'Gobolka Bari',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 50.0, 'lat': 10.0}},
#  {'id': 64670,
#   'name': 'Bargaal',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 51.077301, 'lat': 11.28636}},
#  {'id': 64814,
#   'name': 'Bandarbeyla',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 50.812199, 'lat': 9.4942}},
#  {'id': 64833,
#   'name': 'Gobolka Banaadir',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.400002, 'lat': 2.11667}},
#  {'id': 65170,
#   'name': 'Baardheere',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 42.27644, 'lat': 2.34464}},
#  {'id': 65785,
#   'name': 'Afgooye',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 45.121201, 'lat': 2.1381}},
#  {'id': 65893,
#   'name': 'Cadayo',
#   'state': '',
#   'country': 'SO',
#   'coord': {'lon': 46.372108, 'lat': 4.39024}},
#  {'id': 66093,
#   'name': 'Yasuj',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 51.587959, 'lat': 30.66824}},
#  {'id': 66108,
#   'name': 'Shāhrūd',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 55.01667, 'lat': 36.416672}},
#  {'id': 69349,
#   'name': '‘Abbāsābād-e Qūsheh',
#   'state': '',
#   'country': 'IR',
#   'coord': {'lon': 59.216671, 'lat': 32.866669}},
#  {'id': 69372,
#   'name': 'At Tawilah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.74778, 'lat': 15.49389}},
#  {'id': 69426,
#   'name': 'Zinjibar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.38073, 'lat': 13.12871}},
#  {'id': 69457,
#   'name': 'Zarajah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.378681, 'lat': 14.86692}},
#  {'id': 69482,
#   'name': 'Az Zahir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.48333, 'lat': 13.96667}},
#  {'id': 69499,
#   'name': 'Zabīd',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.368408, 'lat': 14.27742}},
#  {'id': 69500,
#   'name': 'Zabid',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.315182, 'lat': 14.1951}},
#  {'id': 69537,
#   'name': 'Yufrus',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.947041, 'lat': 13.45529}},
#  {'id': 69543,
#   'name': 'Republic of Yemen',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.5, 'lat': 15.5}},
#  {'id': 69558,
#   'name': 'Yarīm',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.31176, 'lat': 14.25388}},
#  {'id': 69559,
#   'name': 'Yarim',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.377949, 'lat': 14.29804}},
#  {'id': 69640,
#   'name': 'Washhah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.41066, 'lat': 16.307739}},
#  {'id': 69684,
#   'name': 'Walan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.276409, 'lat': 15.07021}},
#  {'id': 69686,
#   'name': 'Dhi Jalal',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.707539, 'lat': 13.62378}},
#  {'id': 69769,
#   'name': 'Usaylan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.82832, 'lat': 15.03201}},
#  {'id': 69944,
#   'name': 'Ubal',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.544441, 'lat': 14.98808}},
#  {'id': 70080,
#   'name': 'Thamud',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.916672, 'lat': 17.299999}},
#  {'id': 70160,
#   'name': 'Tarim',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.99889, 'lat': 16.05694}},
#  {'id': 70221,
#   'name': 'At Ta‘izzīyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.009411, 'lat': 13.69479}},
#  {'id': 70222,
#   'name': 'Muḩāfaz̧at Ta‘izz',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.0, 'lat': 13.5}},
#  {'id': 70223,
#   'name': 'Ta‘izz',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.033329, 'lat': 14.78333}},
#  {'id': 70225,
#   'name': 'Taizz',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.020908, 'lat': 13.57952}},
#  {'id': 70272,
#   'name': 'As Suwayda',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.2304, 'lat': 13.78694}},
#  {'id': 70346,
#   'name': 'Al Anan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.312519, 'lat': 16.72188}},
#  {'id': 70357,
#   'name': 'Abs',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.197239, 'lat': 16.002951}},
#  {'id': 70551,
#   'name': 'Sif',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.330002, 'lat': 15.31389}},
#  {'id': 70600,
#   'name': 'Shuḩayr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.392502, 'lat': 14.68417}},
#  {'id': 70656,
#   'name': 'Shihan as Sufla',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 52.48925, 'lat': 17.769991}},
#  {'id': 70677,
#   'name': 'Shibam',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.904449, 'lat': 15.50943}},
#  {'id': 70759,
#   'name': 'Ash Sharyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.022442, 'lat': 14.35659}},
#  {'id': 70808,
#   'name': 'Sharas',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.64925, 'lat': 15.71233}},
#  {'id': 70910,
#   'name': 'Shaharat al Ghis',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.702278, 'lat': 16.184111}},
#  {'id': 70935,
#   'name': 'Muḩāfaz̧at Shabwah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.0, 'lat': 15.0}},
#  {'id': 70979,
#   'name': 'Sayyan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.324421, 'lat': 15.17177}},
#  {'id': 71005,
#   'name': 'Sayhut',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 51.24556, 'lat': 15.21056}},
#  {'id': 71131,
#   'name': 'Sanhan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.305698, 'lat': 15.2252}},
#  {'id': 71132,
#   'name': 'Sanaa',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.4249, 'lat': 15.26069}},
#  {'id': 71136,
#   'name': 'Sana',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.76667, 'lat': 15.4}},
#  {'id': 71137,
#   'name': 'Sanaa',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.206669, 'lat': 15.35472}},
#  {'id': 71273,
#   'name': 'Sahar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.308578, 'lat': 15.31586}},
#  {'id': 71282,
#   'name': 'Sah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.850559, 'lat': 15.57722}},
#  {'id': 71333,
#   'name': 'Muḩāfaz̧at Şa‘dah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.914879, 'lat': 17.0634}},
#  {'id': 71334,
#   'name': 'Sadah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.763939, 'lat': 16.94021}},
#  {'id': 71481,
#   'name': 'Rihab',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.188141, 'lat': 14.22762}},
#  {'id': 71491,
#   'name': 'Rada',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.83709, 'lat': 14.4151}},
#  {'id': 71532,
#   'name': 'Muḩāfaz̧at Raymah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.666672, 'lat': 14.63333}},
#  {'id': 71549,
#   'name': 'Ar Raydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 50.479172, 'lat': 15.035}},
#  {'id': 71558,
#   'name': 'Raydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.040852, 'lat': 15.81421}},
#  {'id': 71622,
#   'name': 'Rakkat al ‘Askarī',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.48333, 'lat': 16.15}},
#  {'id': 71687,
#   'name': 'Rudum',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.743141, 'lat': 14.0851}},
#  {'id': 71799,
#   'name': 'Qulansiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 53.48333, 'lat': 12.68333}},
#  {'id': 71834,
#   'name': 'Qishn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 51.681389, 'lat': 15.42278}},
#  {'id': 71904,
#   'name': 'Qatabah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.705799, 'lat': 13.85493}},
#  {'id': 72181,
#   'name': 'Nisab',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.5, 'lat': 14.51667}},
#  {'id': 72430,
#   'name': 'Al Musaymir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.61528, 'lat': 13.44389}},
#  {'id': 72519,
#   'name': 'Mukayras',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.670738, 'lat': 13.94428}},
#  {'id': 72557,
#   'name': 'Mudiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.082539, 'lat': 13.9284}},
#  {'id': 72561,
#   'name': 'Markaz Mudhaykirah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.9688, 'lat': 13.88953}},
#  {'id': 72589,
#   'name': 'Morī',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 53.900002, 'lat': 12.63333}},
#  {'id': 72647,
#   'name': 'Manwakh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.109169, 'lat': 16.807779}},
#  {'id': 72746,
#   'name': 'Mayfaah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.561199, 'lat': 14.27042}},
#  {'id': 72752,
#   'name': 'Maidi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.812988, 'lat': 16.321011}},
#  {'id': 72760,
#   'name': 'Mawza',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.50993, 'lat': 13.26831}},
#  {'id': 72781,
#   'name': 'Mawiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.347679, 'lat': 13.58294}},
#  {'id': 72855,
#   'name': 'Al Jawl',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.280659, 'lat': 14.45625}},
#  {'id': 72965,
#   'name': 'Marib City',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.303398, 'lat': 15.4156}},
#  {'id': 72966,
#   'name': 'Muḩāfaz̧at Ma’rib',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.32534, 'lat': 15.4591}},
#  {'id': 72968,
#   'name': "Ma'rib",
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.325809, 'lat': 15.46253}},
#  {'id': 73091,
#   'name': 'Manakhah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.741562, 'lat': 15.07422}},
#  {'id': 73100,
#   'name': 'Milah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.786221, 'lat': 14.41617}},
#  {'id': 73125,
#   'name': 'Al Malahit',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.275822, 'lat': 16.76848}},
#  {'id': 73325,
#   'name': 'Al Mafud',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.252171, 'lat': 15.34264}},
#  {'id': 73331,
#   'name': 'Mafhaq',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.903042, 'lat': 15.10162}},
#  {'id': 73365,
#   'name': 'Al Madid',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.47337, 'lat': 15.64453}},
#  {'id': 73409,
#   'name': 'Mabar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.293541, 'lat': 14.79395}},
#  {'id': 73422,
#   'name': 'Al Maalla',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.002441, 'lat': 12.78987}},
#  {'id': 73504,
#   'name': 'Lawdar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.868591, 'lat': 13.88282}},
#  {'id': 73560,
#   'name': 'Lahij',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.881939, 'lat': 13.05667}},
#  {'id': 73638,
#   'name': 'Kuhlan Afar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.719021, 'lat': 15.73309}},
#  {'id': 73650,
#   'name': 'Kuaydinah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.3372, 'lat': 15.82104}},
#  {'id': 73668,
#   'name': 'Kitaf',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.109051, 'lat': 17.031651}},
#  {'id': 73685,
#   'name': 'Kilmia',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 52.233318, 'lat': 12.18576}},
#  {'id': 73786,
#   'name': 'Khawr Maksar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.033371, 'lat': 12.81227}},
#  {'id': 73788,
#   'name': 'Khawrah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.15435, 'lat': 14.43201}},
#  {'id': 73861,
#   'name': 'Khamir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.953621, 'lat': 15.98792}},
#  {'id': 74116,
#   'name': 'Juban',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.874599, 'lat': 14.01164}},
#  {'id': 74167,
#   'name': 'Jihanah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.482441, 'lat': 15.22628}},
#  {'id': 74185,
#   'name': 'Jiblah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.146679, 'lat': 13.92162}},
#  {'id': 74219,
#   'name': 'Jawf al Maqbabah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.834881, 'lat': 13.83783}},
#  {'id': 74222,
#   'name': 'Muḩāfaz̧at al Jawf',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.5243, 'lat': 16.597401}},
#  {'id': 74368,
#   'name': 'Jaar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.30558, 'lat': 13.223}},
#  {'id': 74475,
#   'name': 'Ibb',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.155079, 'lat': 14.03356}},
#  {'id': 74477,
#   'name': 'Ibb',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.183331, 'lat': 13.96667}},
#  {'id': 74490,
#   'name': 'Huth',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.96854, 'lat': 16.23114}},
#  {'id': 74499,
#   'name': 'As Salasil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.831532, 'lat': 16.479589}},
#  {'id': 74785,
#   'name': 'Al Abr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.23333, 'lat': 16.133329}},
#  {'id': 74906,
#   'name': 'Hays',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.483101, 'lat': 13.9317}},
#  {'id': 74938,
#   'name': 'Hayfan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.280109, 'lat': 13.31778}},
#  {'id': 75000,
#   'name': 'Hawf',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 53.033329, 'lat': 16.633329}},
#  {'id': 75034,
#   'name': 'Haswayn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 52.102219, 'lat': 15.59194}},
#  {'id': 75133,
#   'name': 'Harib',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.503559, 'lat': 14.93156}},
#  {'id': 75163,
#   'name': 'Harad',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.05883, 'lat': 16.409651}},
#  {'id': 75239,
#   'name': 'Hammam Ali',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.147629, 'lat': 14.66371}},
#  {'id': 75334,
#   'name': 'Ḩajjah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.6063, 'lat': 15.63287}},
#  {'id': 75337,
#   'name': 'Hajjah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.60582, 'lat': 15.69425}},
#  {'id': 75357,
#   'name': 'Madinat Labus',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.25, 'lat': 13.86667}},
#  {'id': 75411,
#   'name': 'Muḩāfaz̧at Ḩaḑramawt',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.0, 'lat': 16.0}},
#  {'id': 75427,
#   'name': 'Tamrida',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 54.033329, 'lat': 12.65}},
#  {'id': 75504,
#   'name': 'Habil al Jabr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.985779, 'lat': 13.60422}},
#  {'id': 75508,
#   'name': 'Al Habilayn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.850761, 'lat': 13.52002}},
#  {'id': 75518,
#   'name': 'Habban',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.076488, 'lat': 14.35411}},
#  {'id': 75539,
#   'name': 'Hababah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.875629, 'lat': 15.54418}},
#  {'id': 75618,
#   'name': 'Ghayl Ba Wazir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.366112, 'lat': 14.77611}},
#  {'id': 76089,
#   'name': 'Dhubab',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.41024, 'lat': 12.94305}},
#  {'id': 76125,
#   'name': 'Dhi Naim',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.448071, 'lat': 14.10574}},
#  {'id': 76147,
#   'name': 'Dhaybin',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.129169, 'lat': 15.97712}},
#  {'id': 76153,
#   'name': 'Dhī as Sufāl',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.077751, 'lat': 13.82137}},
#  {'id': 76154,
#   'name': 'Dhi as Sufal',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.114689, 'lat': 13.83446}},
#  {'id': 76182,
#   'name': 'Madīnat Dhamār',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.403389, 'lat': 14.60684}},
#  {'id': 76183,
#   'name': 'Muḩāfaz̧at Dhamār',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.272942, 'lat': 14.68296}},
#  {'id': 76184,
#   'name': 'Dhamar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.40514, 'lat': 14.54274}},
#  {'id': 76362,
#   'name': 'Dawran ad Daydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.206638, 'lat': 14.73927}},
#  {'id': 76482,
#   'name': 'Dar an Nasr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.016338, 'lat': 13.55821}},
#  {'id': 76699,
#   'name': 'Burum',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.979721, 'lat': 14.36361}},
#  {'id': 76927,
#   'name': 'Bayt Adhaqah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.702278, 'lat': 15.61576}},
#  {'id': 76930,
#   'name': 'As Suq al Jadid',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.062038, 'lat': 15.82496}},
#  {'id': 76989,
#   'name': 'Bayt al Faqīh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.278149, 'lat': 14.48738}},
#  {'id': 76991,
#   'name': 'Bayt al Faqih',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.324459, 'lat': 14.51635}},
#  {'id': 77017,
#   'name': 'Bayhan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.718891, 'lat': 14.80067}},
#  {'id': 77278,
#   'name': 'Bani Hujjaj',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.316669, 'lat': 15.41667}},
#  {'id': 77307,
#   'name': 'Bani Bakr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.26667, 'lat': 13.93333}},
#  {'id': 77407,
#   'name': 'Bājil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.1735, 'lat': 15.07561}},
#  {'id': 77408,
#   'name': 'Bajil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.285061, 'lat': 15.05835}},
#  {'id': 77504,
#   'name': 'Az Zuhrah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.995819, 'lat': 15.72377}},
#  {'id': 77515,
#   'name': 'Az Zaydiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.008121, 'lat': 15.32851}},
#  {'id': 77529,
#   'name': 'Az Zahir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.488178, 'lat': 16.317989}},
#  {'id': 77594,
#   'name': 'Al Hajab',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.529041, 'lat': 14.85192}},
#  {'id': 77636,
#   'name': 'Al Awabil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.864311, 'lat': 13.83754}},
#  {'id': 77646,
#   'name': 'At Turbah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.124149, 'lat': 13.2127}},
#  {'id': 77655,
#   'name': 'Al Tuhayta',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.226372, 'lat': 14.18356}},
#  {'id': 77662,
#   'name': 'At Tawahi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.980202, 'lat': 12.78471}},
#  {'id': 77726,
#   'name': 'Ataq',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.831871, 'lat': 14.53766}},
#  {'id': 77772,
#   'name': 'As Sudah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.78083, 'lat': 15.95861}},
#  {'id': 77791,
#   'name': 'As Sayyani',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.17395, 'lat': 13.84266}},
#  {'id': 77800,
#   'name': 'As Sawmaah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.801022, 'lat': 14.08505}},
#  {'id': 77803,
#   'name': 'Al Bilad',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.291672, 'lat': 16.13806}},
#  {'id': 77809,
#   'name': 'As Sawadiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.221481, 'lat': 14.30113}},
#  {'id': 77843,
#   'name': 'As Salif',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.67067, 'lat': 15.30558}},
#  {'id': 77862,
#   'name': 'Said',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.872921, 'lat': 14.33011}},
#  {'id': 77872,
#   'name': 'As Safaqayn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.421211, 'lat': 15.37897}},
#  {'id': 77881,
#   'name': 'As Saddah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.421391, 'lat': 14.1221}},
#  {'id': 77940,
#   'name': 'Ash Shaykh Uthman',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.993092, 'lat': 12.87678}},
#  {'id': 77946,
#   'name': 'Ash Shatt',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.035709, 'lat': 12.89357}},
#  {'id': 77980,
#   'name': 'Ash Shahil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.404949, 'lat': 15.86656}},
#  {'id': 77985,
#   'name': 'Ash Shaghadirah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.520561, 'lat': 15.62}},
#  {'id': 78019,
#   'name': 'Asdas',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.081509, 'lat': 15.76601}},
#  {'id': 78112,
#   'name': 'Marbat',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.388111, 'lat': 14.20567}},
#  {'id': 78137,
#   'name': 'Ar Rawdah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.223991, 'lat': 15.43251}},
#  {'id': 78141,
#   'name': 'Ar Rawdah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.276379, 'lat': 14.46725}},
#  {'id': 78379,
#   'name': 'An Nadirah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.47559, 'lat': 14.09628}},
#  {'id': 78428,
#   'name': 'Amran',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.943851, 'lat': 15.6594}},
#  {'id': 78448,
#   'name': 'Amd',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.98333, 'lat': 15.3}},
#  {'id': 78471,
#   'name': 'Al Wuday',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.01786, 'lat': 13.7721}},
#  {'id': 78543,
#   'name': 'Al Udayn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.996731, 'lat': 13.96918}},
#  {'id': 78566,
#   'name': 'Al Qurh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 51.48333, 'lat': 16.73333}},
#  {'id': 78638,
#   'name': 'Al Qaryah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.680981, 'lat': 13.94067}},
#  {'id': 78675,
#   'name': 'Al Qanawis',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.134331, 'lat': 15.49277}},
#  {'id': 78699,
#   'name': 'Al Qaflah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.767921, 'lat': 16.31897}},
#  {'id': 78708,
#   'name': 'Qaryat al Qabil',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.127682, 'lat': 15.45033}},
#  {'id': 78713,
#   'name': 'Al Maudah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.387321, 'lat': 14.21055}},
#  {'id': 78742,
#   'name': 'Al Munirah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.929359, 'lat': 15.32024}},
#  {'id': 78754,
#   'name': 'Al Mukalla',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.124241, 'lat': 14.54248}},
#  {'id': 78776,
#   'name': 'Al Misrakh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.020432, 'lat': 13.46059}},
#  {'id': 78814,
#   'name': 'Al Milah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.825562, 'lat': 13.42611}},
#  {'id': 78823,
#   'name': 'Al Mighlaf',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.18914, 'lat': 15.2871}},
#  {'id': 78905,
#   'name': 'Markaz al Marir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.59547, 'lat': 13.98178}},
#  {'id': 78909,
#   'name': 'Al Marawiah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.153912, 'lat': 14.83069}},
#  {'id': 78929,
#   'name': 'Al Mansuriyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.299221, 'lat': 14.6856}},
#  {'id': 78931,
#   'name': 'Al Mansurah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.981659, 'lat': 12.86019}},
#  {'id': 78964,
#   'name': 'Al Makhadir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.19796, 'lat': 14.12224}},
#  {'id': 78966,
#   'name': 'Al Makdash',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.650002, 'lat': 14.18333}},
#  {'id': 78977,
#   'name': 'Al Mahwit',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.544811, 'lat': 15.47007}},
#  {'id': 78991,
#   'name': 'Al Mahfid',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.91328, 'lat': 14.05847}},
#  {'id': 79006,
#   'name': 'Al Mahabishah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.435871, 'lat': 15.94758}},
#  {'id': 79050,
#   'name': 'Al Luhayyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.690929, 'lat': 15.70309}},
#  {'id': 79088,
#   'name': 'Kirsh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.490459, 'lat': 13.36473}},
#  {'id': 79131,
#   'name': 'Al Khawkhah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.249298, 'lat': 13.8071}},
#  {'id': 79133,
#   'name': 'Al Khasamah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.102188, 'lat': 15.32345}},
#  {'id': 79219,
#   'name': 'Al Jurbah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.158939, 'lat': 13.7915}},
#  {'id': 79284,
#   'name': 'Al Jarrahi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.388451, 'lat': 14.13254}},
#  {'id': 79384,
#   'name': 'Al Husayn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.76886, 'lat': 13.79199}},
#  {'id': 79393,
#   'name': 'Huraydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.182781, 'lat': 15.59861}},
#  {'id': 79415,
#   'name': 'Al Hudaydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 42.954521, 'lat': 14.79781}},
#  {'id': 79416,
#   'name': 'Muḩāfaz̧at al Ḩudaydah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.192791, 'lat': 14.91732}},
#  {'id': 79455,
#   'name': 'Al Hazm',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.77692, 'lat': 16.164061}},
#  {'id': 79478,
#   'name': 'Al Qatn',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.455559, 'lat': 15.84056}},
#  {'id': 79531,
#   'name': 'Al Harf',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.094212, 'lat': 16.363951}},
#  {'id': 79561,
#   'name': 'Al Ḩamzāt',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.73333, 'lat': 16.966669}},
#  {'id': 79609,
#   'name': 'Hajar al Mushaikh',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 47.833328, 'lat': 16.133329}},
#  {'id': 79657,
#   'name': 'Al Ḩabīt',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.799999, 'lat': 14.75}},
#  {'id': 79700,
#   'name': 'Al Ghayzah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 52.176048, 'lat': 16.20787}},
#  {'id': 79737,
#   'name': 'Al Fujayr',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.799999, 'lat': 15.96667}},
#  {'id': 79836,
#   'name': 'Al Bayda',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.57272, 'lat': 13.98523}},
#  {'id': 79838,
#   'name': 'Muḩāfaz̧at al Bayḑā’',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.394421, 'lat': 14.34166}},
#  {'id': 79845,
#   'name': 'Al Batinah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.433331, 'lat': 15.48333}},
#  {'id': 79967,
#   'name': 'Al Aqir',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 45.91156, 'lat': 14.56816}},
#  {'id': 80105,
#   'name': 'Ahwar',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.713669, 'lat': 13.52019}},
#  {'id': 80309,
#   'name': 'Ad Durayhimi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.05505, 'lat': 14.63702}},
#  {'id': 80331,
#   'name': 'Ad Dis ash Sharqiyah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 49.947781, 'lat': 14.90806}},
#  {'id': 80336,
#   'name': 'Ad Dimnah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.181679, 'lat': 13.45398}},
#  {'id': 80379,
#   'name': 'Ad Dann',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.852749, 'lat': 14.3518}},
#  {'id': 80383,
#   'name': 'Az Zaliah',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 48.01667, 'lat': 15.01667}},
#  {'id': 80384,
#   'name': 'Dhalie',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.731369, 'lat': 13.69572}},
#  {'id': 80393,
#   'name': 'Dhahi',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 43.06974, 'lat': 15.21467}},
#  {'id': 80412,
#   'name': 'Muḩāfaz̧at ‘Adan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 44.916672, 'lat': 12.83333}},
#  {'id': 80425,
#   'name': 'Muḩāfaz̧at Abyan',
#   'state': '',
#   'country': 'YE',
#   'coord': {'lon': 46.125999, 'lat': 13.6291}},
#  {'id': 80509,
#   'name': 'Al Bardīyah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 25.086531, 'lat': 31.756149}},
#  {'id': 81302,
#   'name': 'Tobruk',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 23.976391, 'lat': 32.083611}},
#  {'id': 81604,
#   'name': 'Qaryat Sulūq',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.25205, 'lat': 31.66818}},
#  {'id': 85820,
#   'name': 'Kamb al ‘Ajjāj',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.25659, 'lat': 32.097271}},
#  {'id': 86049,
#   'name': 'Gialo',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.549999, 'lat': 29.033331}},
#  {'id': 87204,
#   'name': 'Darnah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 22.533331, 'lat': 32.049999}},
#  {'id': 87205,
#   'name': 'Darnah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 22.63669, 'lat': 32.76704}},
#  {'id': 88319,
#   'name': 'Benghazi',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.066669, 'lat': 32.116669}},
#  {'id': 88380,
#   'name': 'Az Zuwaytīnah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.12022, 'lat': 30.9522}},
#  {'id': 88533,
#   'name': 'Awjilah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.28694, 'lat': 29.108061}},
#  {'id': 88562,
#   'name': 'At Tāj',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 23.2857, 'lat': 24.20487}},
#  {'id': 88603,
#   'name': 'Aş Şafşāf',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.94923, 'lat': 32.777458}},
#  {'id': 88635,
#   'name': 'Ash Shawāshinah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.29417, 'lat': 29.171671}},
#  {'id': 88823,
#   'name': 'Al ‘Urūbah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.066669, 'lat': 32.116669}},
#  {'id': 88834,
#   'name': 'Tūkrah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.579109, 'lat': 32.534142}},
#  {'id': 88835,
#   'name': 'Al Qubbah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 22.242371, 'lat': 32.76162}},
#  {'id': 88903,
#   'name': 'Al Marj',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.831739, 'lat': 32.48798}},
#  {'id': 88904,
#   'name': 'Al Marj',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.316669, 'lat': 31.933331}},
#  {'id': 88930,
#   'name': 'Al Kufrah',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 23.269621, 'lat': 24.16667}},
#  {'id': 88962,
#   'name': 'Al Jawf',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 23.29093, 'lat': 24.1989}},
#  {'id': 88967,
#   'name': 'Al Jaghbūb',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 24.51676, 'lat': 29.74262}},
#  {'id': 89055,
#   'name': 'Al Bayḑā’',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 21.75506, 'lat': 32.762718}},
#  {'id': 89087,
#   'name': 'Al Abyār',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.596531, 'lat': 32.189999}},
#  {'id': 89113,
#   'name': 'Ajdabiya',
#   'state': '',
#   'country': 'LY',
#   'coord': {'lon': 20.226259, 'lat': 30.755449}},
#  {'id': 89341,
#   'name': 'Muḩāfaz̧at al Başrah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 47.25, 'lat': 30.33333}},
#  {'id': 89570,
#   'name': 'Zaxo',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 42.700081, 'lat': 37.14817}},
#  {'id': 89693,
#   'name': 'Muhafazat Wasit',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 45.416672, 'lat': 32.75}},
#  {'id': 89824,
#   'name': 'Umm Qaşr',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 47.916771, 'lat': 30.040541}},
#  {'id': 89977,
#   'name': 'Ūlwur',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 45.749722, 'lat': 35.115002}},
#  {'id': 90026,
#   'name': 'Tozkhurmato',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 44.62994, 'lat': 34.890461}},
#  {'id': 90150,
#   'name': 'Tikrīt',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.678219, 'lat': 34.607121}},
#  {'id': 90353,
#   'name': 'Tallkayf',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.119171, 'lat': 36.489441}},
#  {'id': 90552,
#   'name': 'Sulaymānīyah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 42.381939, 'lat': 34.149719}},
#  {'id': 90708,
#   'name': 'Sīnah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.03886, 'lat': 36.809021}},
#  {'id': 91597,
#   'name': 'Sāmarrā’',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.875622, 'lat': 34.200958}},
#  {'id': 91695,
#   'name': 'Muhafazat Salah ad Din',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.650002, 'lat': 34.5}},
#  {'id': 91812,
#   'name': 'Nāḩīyat Saddat al Hindīyah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 44.280281, 'lat': 32.714722}},
#  {'id': 91823,
#   'name': 'Aḩmad Ţāhir',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 45.333328, 'lat': 34.316669}},
#  {'id': 92002,
#   'name': 'Ṟuwandiz',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 44.531109, 'lat': 36.61631}},
#  {'id': 92004,
#   'name': 'Rāwah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 41.909302, 'lat': 34.48164}},
#  {'id': 92244,
#   'name': 'Qāzaw al ‘Ulyā',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 45.692501, 'lat': 35.338333}},
#  {'id': 92365,
#   'name': 'Qaryat Bānī Mālik',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 47.700001, 'lat': 30.566669}},
#  {'id': 92430,
#   'name': 'Al-Hamdaniya',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 43.37373, 'lat': 36.271461}},
#  {'id': 92628,
#   'name': 'Qal‘at as Sādah',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 44.157219, 'lat': 33.161388}},
#  {'id': 92873,
#   'name': 'Niskah Jaww',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 45.648056, 'lat': 35.353333}},
#  {'id': 92877,
#   'name': 'Muḩāfaz̧at Nīnawá',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 42.583328, 'lat': 36.166672}},
#  {'id': 93396,
#   'name': 'Mudarras',
#   'state': '',
#   'country': 'IQ',
#   'coord': {'lon': 47.183331, 'lat': 31.85}},
#  {'id': 93540,
#   'name': 'Muḩāfaz̧at Maysān',
# ...
#   'coord': {'lon': 32.79583, 'lat': 34.779171}},
#  {'id': 146267,
#   'name': 'Eparchía Lefkosías',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.200001, 'lat': 35.066669}},
#  {'id': 146268,
#   'name': 'Nicosia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.366669, 'lat': 35.166672}},
#  {'id': 146278,
#   'name': 'Mouttagiáka',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.099998, 'lat': 34.720829}},
#  {'id': 146283,
#   'name': 'Mosfilotí',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.429169, 'lat': 34.950001}},
#  {'id': 146286,
#   'name': 'Mórfou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.99139, 'lat': 35.198059}},
#  {'id': 146303,
#   'name': 'Mesógi',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.458328, 'lat': 34.816669}},
#  {'id': 146311,
#   'name': 'Meneou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.570831, 'lat': 34.849998}},
#  {'id': 146347,
#   'name': 'Mámmari',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.200001, 'lat': 35.166672}},
#  {'id': 146358,
#   'name': 'Lythrodóntas',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.29583, 'lat': 34.950001}},
#  {'id': 146362,
#   'name': 'Lýmpia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.462502, 'lat': 35.0}},
#  {'id': 146371,
#   'name': 'Livádia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.629169, 'lat': 34.95417}},
#  {'id': 146375,
#   'name': 'Liopétri',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.89167, 'lat': 35.008331}},
#  {'id': 146383,
#   'name': 'Eparchía Lemesoú',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.916672, 'lat': 34.783329}},
#  {'id': 146384,
#   'name': 'Limassol',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.033329, 'lat': 34.674999}},
#  {'id': 146386,
#   'name': 'Leonárisso',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 34.14167, 'lat': 35.470829}},
#  {'id': 146391,
#   'name': 'Lefkónoiko',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.73333, 'lat': 35.258331}},
#  {'id': 146392,
#   'name': 'Léfka',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.850559, 'lat': 35.110561}},
#  {'id': 146398,
#   'name': 'Eparchía Lárnakas',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.916672, 'lat': 34.950001}},
#  {'id': 146400,
#   'name': 'Larnaca',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.629169, 'lat': 34.916672}},
#  {'id': 146403,
#   'name': 'Lápithos',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.179169, 'lat': 35.337502}},
#  {'id': 146411,
#   'name': 'Eparchía Kerýneias',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.26667, 'lat': 35.25}},
#  {'id': 146412,
#   'name': 'Kyrenia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.316669, 'lat': 35.341671}},
#  {'id': 146414,
#   'name': 'Kyperoúnta',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.974998, 'lat': 34.9375}},
#  {'id': 146438,
#   'name': 'Kórnos',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.39167, 'lat': 34.92083}},
#  {'id': 146445,
#   'name': 'Kofínou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.387501, 'lat': 34.825001}},
#  {'id': 146451,
#   'name': 'Kolossi',
#   'state': '',
#   'country': 'GB',
#   'coord': {'lon': 32.929169, 'lat': 34.67083}},
#  {'id': 146455,
#   'name': 'Kokkinotrimithiá',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.200001, 'lat': 35.154171}},
#  {'id': 146461,
#   'name': 'Klírou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.179169, 'lat': 35.020828}},
#  {'id': 146469,
#   'name': 'Kíti',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.575001, 'lat': 34.849998}},
#  {'id': 146472,
#   'name': 'Kissonerga',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.400002, 'lat': 34.825001}},
#  {'id': 146490,
#   'name': 'Chlórakas',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.408329, 'lat': 34.804169}},
#  {'id': 146515,
#   'name': 'Káto Pýrgos',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.682499, 'lat': 35.180279}},
#  {'id': 146529,
#   'name': 'Káto Defterá',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.279171, 'lat': 35.087502}},
#  {'id': 146582,
#   'name': 'Kakopetriá',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.904171, 'lat': 34.991669}},
#  {'id': 146615,
#   'name': 'Eparchía Ammochóstou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.866669, 'lat': 35.333328}},
#  {'id': 146617,
#   'name': 'Famagusta',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.950001, 'lat': 35.125}},
#  {'id': 146628,
#   'name': 'Erími',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.916672, 'lat': 34.679169}},
#  {'id': 146633,
#   'name': 'Episkopí',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.899719, 'lat': 34.671379}},
#  {'id': 146639,
#   'name': 'Emba',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.424999, 'lat': 34.808331}},
#  {'id': 146654,
#   'name': 'Dhromolaxia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.586842, 'lat': 34.875511}},
#  {'id': 146661,
#   'name': 'Derýneia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.958328, 'lat': 35.066669}},
#  {'id': 146666,
#   'name': 'Dáli',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.42083, 'lat': 35.025002}},
#  {'id': 146669,
#   'name': 'Republic of Cyprus',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.0, 'lat': 35.0}},
#  {'id': 146692,
#   'name': 'Ágios Týchon',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.14167, 'lat': 34.724998}},
#  {'id': 146748,
#   'name': 'Ayia Napa',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 34.001831, 'lat': 34.982128}},
#  {'id': 146761,
#   'name': 'Avgórou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.84029, 'lat': 35.03688}},
#  {'id': 146767,
#   'name': 'Áchna',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.783329, 'lat': 35.058331}},
#  {'id': 146768,
#   'name': 'Athíenou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.541672, 'lat': 35.066669}},
#  {'id': 146769,
#   'name': 'Athalássa',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.400002, 'lat': 35.145828}},
#  {'id': 146770,
#   'name': 'Astromerítis',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.037498, 'lat': 35.14167}},
#  {'id': 146778,
#   'name': 'Asínou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.979172, 'lat': 35.04583}},
#  {'id': 146791,
#   'name': 'Ergátes',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.245831, 'lat': 35.054169}},
#  {'id': 146796,
#   'name': 'Aradíppou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.591671, 'lat': 34.950001}},
#  {'id': 146797,
#   'name': 'Aredioú',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.195831, 'lat': 35.04583}},
#  {'id': 146834,
#   'name': 'Alámpra',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.400002, 'lat': 34.991669}},
#  {'id': 146839,
#   'name': 'Akrotiri',
#   'state': '',
#   'country': 'GB',
#   'coord': {'lon': 32.958328, 'lat': 34.604172}},
#  {'id': 146842,
#   'name': 'Acherítou',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.862499, 'lat': 35.099998}},
#  {'id': 146844,
#   'name': 'Achéleia',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 32.487499, 'lat': 34.741669}},
#  {'id': 146850,
#   'name': 'Akáki',
#   'state': '',
#   'country': 'CY',
#   'coord': {'lon': 33.129169, 'lat': 35.133331}},
#  {'id': 146862,
#   'name': 'Prishibinskoye',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.593609, 'lat': 39.119579}},
#  {'id': 146879,
#   'name': 'Beylagan Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.666672, 'lat': 39.75}},
#  {'id': 146900,
#   'name': 'Zangilan Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.666672, 'lat': 39.083328}},
#  {'id': 146901,
#   'name': 'Zangilan',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.651192, 'lat': 39.088341}},
#  {'id': 146961,
#   'name': 'Yardımlı',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.237221, 'lat': 38.920559}},
#  {'id': 146962,
#   'name': 'Yardymli Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.25, 'lat': 38.916672}},
#  {'id': 146969,
#   'name': 'Novyy Karanlug',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.10989, 'lat': 39.79546}},
#  {'id': 146970,
#   'name': 'Xankandi',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.7528, 'lat': 39.817699}},
#  {'id': 147059,
#   'name': 'Əhmədbəyli',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.399021, 'lat': 39.87867}},
#  {'id': 147105,
#   'name': 'Shushi',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.749191, 'lat': 39.75893}},
#  {'id': 147192,
#   'name': 'Shekyarabad',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 45.43676, 'lat': 39.19228}},
#  {'id': 147269,
#   'name': 'Salyan Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 49.0, 'lat': 39.666672}},
#  {'id': 147271,
#   'name': 'Salyan',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.980549, 'lat': 39.59362}},
#  {'id': 147278,
#   'name': 'Şahbuz',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 45.573891, 'lat': 39.407219}},
#  {'id': 147282,
#   'name': 'Sedarak',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 44.88805, 'lat': 39.711441}},
#  {'id': 147284,
#   'name': 'Sabirabad Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.666672, 'lat': 39.916672}},
#  {'id': 147287,
#   'name': 'Saatly Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.416672, 'lat': 39.833328}},
#  {'id': 147305,
#   'name': 'Qubadlı',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.581959, 'lat': 39.34396}},
#  {'id': 147307,
#   'name': 'Qaraçala',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.952301, 'lat': 39.813179}},
#  {'id': 147310,
#   'name': 'Bilasuvar Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.416672, 'lat': 39.5}},
#  {'id': 147364,
#   'name': 'Orjonikidze',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.690762, 'lat': 39.632221}},
#  {'id': 147368,
#   'name': 'Ordubad',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.023411, 'lat': 38.905949}},
#  {'id': 147422,
#   'name': 'Neftchala Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 49.0, 'lat': 39.333328}},
#  {'id': 147425,
#   'name': 'Neftçala',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 49.247219, 'lat': 39.374168}},
#  {'id': 147429,
#   'name': 'Nakhchivan',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 45.41222, 'lat': 39.208889}},
#  {'id': 147435,
#   'name': 'Nakhchivan Autonomous Republic',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 45.418171, 'lat': 39.209911}},
#  {'id': 147504,
#   'name': 'Mincivan',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.718472, 'lat': 39.02935}},
#  {'id': 147551,
#   'name': 'Masally District',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.666672, 'lat': 39.0}},
#  {'id': 147552,
#   'name': 'Masally',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.665401, 'lat': 39.03532}},
#  {'id': 147610,
#   'name': 'Lerik Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.416672, 'lat': 38.75}},
#  {'id': 147611,
#   'name': 'Lerik',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.412788, 'lat': 38.772629}},
#  {'id': 147613,
#   'name': 'Lankaran Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.755508, 'lat': 38.70071}},
#  {'id': 147622,
#   'name': 'Lankaran',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.85062, 'lat': 38.75428}},
#  {'id': 147625,
#   'name': 'Laçın',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.550449, 'lat': 39.598808}},
#  {'id': 147626,
#   'name': 'Laçın Rayonu',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.416672, 'lat': 39.666672}},
#  {'id': 147694,
#   'name': 'Qubadli Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.583328, 'lat': 39.333328}},
#  {'id': 147695,
#   'name': 'Qırmızı Bazar',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.948841, 'lat': 39.678329}},
#  {'id': 147727,
#   'name': 'Kizhaba',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.816669, 'lat': 38.53278}},
#  {'id': 147774,
#   'name': 'Xocalı',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.790279, 'lat': 39.912971}},
#  {'id': 147784,
#   'name': 'Xıllı',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 49.101662, 'lat': 39.430119}},
#  {'id': 147982,
#   'name': 'Imishli',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.059952, 'lat': 39.870949}},
#  {'id': 147983,
#   'name': 'Imishli Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.083328, 'lat': 39.833328}},
#  {'id': 148003,
#   'name': 'Horadiz',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.335312, 'lat': 39.448769}},
#  {'id': 148088,
#   'name': 'Haftoni',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.76223, 'lat': 38.763248}},
#  {'id': 148105,
#   'name': 'Hadrut',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.031799, 'lat': 39.52002}},
#  {'id': 148107,
#   'name': 'Fizuli Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.333328, 'lat': 39.583328}},
#  {'id': 148140,
#   'name': 'Jabrayil District',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.0, 'lat': 39.333328}},
#  {'id': 148141,
#   'name': 'Jebrail',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.028339, 'lat': 39.39917}},
#  {'id': 148155,
#   'name': 'Jalilabad',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.5, 'lat': 39.25}},
#  {'id': 148251,
#   'name': 'Culfa',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 45.630798, 'lat': 38.955799}},
#  {'id': 148290,
#   'name': 'Jalilabad',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.491859, 'lat': 39.209629}},
#  {'id': 148323,
#   'name': 'Boradigah',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.703751, 'lat': 38.933891}},
#  {'id': 148340,
#   'name': 'Pushkino',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.544998, 'lat': 39.458328}},
#  {'id': 148375,
#   'name': 'Severo-Vostotchnyi Bank',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 49.247921, 'lat': 39.411171}},
#  {'id': 148442,
#   'name': 'Astara District',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.666672, 'lat': 38.5}},
#  {'id': 148445,
#   'name': 'Astara',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.874981, 'lat': 38.455978}},
#  {'id': 148449,
#   'name': 'Xocalı Rayonu',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.75, 'lat': 39.833328}},
#  {'id': 148450,
#   'name': 'Askyaran',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.832779, 'lat': 39.936668}},
#  {'id': 148565,
#   'name': 'Şirvan',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 48.928551, 'lat': 39.937881}},
#  {'id': 148615,
#   'name': 'Aghjabadi Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.416672, 'lat': 40.0}},
#  {'id': 148617,
#   'name': 'Aghdam Rayon',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 47.0, 'lat': 40.0}},
#  {'id': 148619,
#   'name': 'Ağdam',
#   'state': '',
#   'country': 'AZ',
#   'coord': {'lon': 46.927361, 'lat': 39.990959}},
#  {'id': 148679,
#   'name': 'Kagera Region',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 31.5, 'lat': -2.0}},
#  {'id': 148724,
#   'name': 'Zanzibar Urban/West Region',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.25, 'lat': -6.16667}},
#  {'id': 148728,
#   'name': 'Zanzibar Central/South Region',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.466671, 'lat': -6.25}},
#  {'id': 148730,
#   'name': 'Zanzibar',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.197929, 'lat': -6.16394}},
#  {'id': 148842,
#   'name': 'Wete',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.729382, 'lat': -5.05589}},
#  {'id': 148942,
#   'name': 'Vwawa',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 32.933331, 'lat': -9.11667}},
#  {'id': 148987,
#   'name': 'Vikindu',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.298489, 'lat': -7.00667}},
#  {'id': 149027,
#   'name': 'Uyovu',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 31.525829, 'lat': -3.28333}},
#  {'id': 149039,
#   'name': 'Uwelini',
#   'state': '',
#   'country': 'TZ',
#   'coord': {'lon': 39.683331, 'lat': -5.4}},
#  ...]

# %%
# map unidecode to city names
cities[0]['name'] = 'Hesar-e Sefid'
# Out:
# {'id': 833,
#  'name': 'Hesar-e Sefid',
#  'state': '',
#  'country': 'IR',
#  'coord': {'lon': 47.159401, 'lat': 34.330502}}
